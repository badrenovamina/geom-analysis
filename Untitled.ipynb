# %%
outfile_directory = os.path.join('data', 'outfiles')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 outfile_directory = os.path.join('data', 'outfiles')
#
# NameError: name 'os' is not defined
